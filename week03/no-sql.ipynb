# %%
# pandas
import pandas as pd
df = pd.read_csv('../data/csv/car_evaluation_processed.csv')
df.head()
# Out:
#    Unnamed: 0 buying  maint  doors  persons lug_boot safety  class
# 0           0  vhigh  vhigh      2        2    small    low  unacc
# 1           1  vhigh  vhigh      2        2    small    med  unacc
# 2           2  vhigh  vhigh      2        2    small   high  unacc
# 3           3  vhigh  vhigh      2        2      med    low  unacc
# 4           4  vhigh  vhigh      2        2      med    med  unacc

# %%
df.to_parquet('../data/parquet/car_evaluation_processed.parquet')

# %% [markdown]
# ![image.png](attachment:a5cf1d4b-8a26-4768-bcb9-9a53cd036c39.png)

# %%
# mongodb

# %%
# redis

import redis

# %%
# spark
